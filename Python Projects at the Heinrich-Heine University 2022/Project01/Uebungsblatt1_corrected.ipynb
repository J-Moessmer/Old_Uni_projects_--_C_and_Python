# %% [markdown]
# # Übungsblatt 1
# Bitte geben Sie die Übungen bis zum 27.4.2022 um 10:00 im Ilias ab. Bei Fragen wenden Sie sich bitte an mafeg100@hhu.de
#
#
# <b>Blatt Gesamt: 10 von 10 Punkten</b>
#
# <b>Alle Blätter: 10 von 10 Punkten</b>

# %% [markdown]
# ## Aufgabe 1 (2 Punkte)
# Schreiben Sie ein Programm, das **alle** Wörter des Gedichts "Für Einen" ausgibt, eins pro Zeile. Die Satzzeichen am Ende der Wörter sollen (wie in der Vorlesung) nicht entfernt werden. Das Gedicht befindet sich in der Datei ``kaleko-fuer-einen.txt``
#
# <b>2 von 2 Punkten:</b>

# %%
f = open("kaleko-fuer-einen.txt", encoding="utf-8")
words = f.read()
f.close()

for word in words.split():
    print(word)
# Out:
# Für
# Einen
# Die
# Andern
# sind
# das
# weite
# Meer.
# Du
# aber
# bist
# der
# Hafen.
# So
# glaube
# mir:
# kannst
# ruhig
# schlafen,
# Ich
# steure
# immer
# wieder
# her.
# Denn
# all
# die
# Stürme,
# die
# mich
# trafen,
# Sie
# ließen
# meine
# Segel
# leer.
# Die
# Andern
# sind
# das
# bunte
# Meer,
# Du
# aber
# bist
# der
# Hafen.
# Du
# bist
# der
# Leuchtturm.
# Letztes
# Ziel.
# Kannst
# Liebster,
# ruhig
# schlafen.
# Die
# Andern...
# das
# ist
# Wellenspiel,
# Du
# aber
# bist
# der
# Hafen.

# %% [markdown]
# ## Aufgabe 2 (4 Punkte)
# Schreiben Sie ein Programm, das alle **kleingeschriebenen** Wörter des Gedichts "Für Einen" ausgibt, eins pro Zeile. Die Satzzeichen am Ende der Wörter sollen (wie in der Vorlesung) nicht entfernt werden.
#
#
# <b>4 von 4 Punkten:</b>

# %%
f = open("kaleko-fuer-einen.txt", encoding="utf-8")
words = f.read()
f.close()

for word in words.split():
    if word.islower():
        print(word)
# Out:
# sind
# das
# weite
# aber
# bist
# der
# glaube
# mir:
# kannst
# ruhig
# schlafen,
# steure
# immer
# wieder
# her.
# all
# die
# die
# mich
# trafen,
# ließen
# meine
# leer.
# sind
# das
# bunte
# aber
# bist
# der
# bist
# der
# ruhig
# schlafen.
# das
# ist
# aber
# bist
# der

# %% [markdown]
# ## Aufgabe 3 (4 Punkte)
# Schreiben Sie ein Programm, das alle englischen Wörter aus dem Wörterbuch (mit Dateinamen ``american-english.txt``) zeilenweise ausgibt, die Kennzeichen in **Düsseldorf** sein können.
#
# <b>4 von 4 Punkten:</b>

# %%
f = open("american-english.txt", encoding="utf-8")
words = f.read()
f.close()

for word in words.split():
    if word.startswith("d") and 2 <= len(word) <= 3:
        print(word)
# Out:
# dab
# dad
# dam
# day
# deb
# den
# dew
# did
# die
# dig
# dim
# din
# dip
# dis
# do
# doc
# doe
# dog
# don
# dos
# dot
# dry
# dub
# dud
# due
# dug
# duh
# dun
# duo
# dye
